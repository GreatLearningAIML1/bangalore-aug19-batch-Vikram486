# %% [markdown]
# # The Iris Dataset
# The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.
#
# The dataset contains a set of 150 records under five attributes - petal length, petal width, sepal length, sepal width and species.

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Import dataset
# - Import iris dataset
# - Import the dataset using sklearn library

# %%
from sklearn.datasets import load_iris
iris_df=load_iris()

# %% [markdown]
# ## Question 2

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - you can get the features using .data method
# - you can get the features using .target method

# %%
import numpy as np
import pandas as pd

# %%
x=iris_df.data
y=iris_df.target

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Create train and test data
# - use train_test_split to get train and test set
# - set a random_state
# - test_size: 0.25

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.25,random_state=50)

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### One-hot encode the labels
# - convert class vectors (integers) to binary class matrix
# - convert labels
# - number of classes: 3
# - we are doing this to use categorical_crossentropy as loss

# %%
from tensorflow.keras.utils import to_categorical

# %%
ytrain=to_categorical(ytrain,3)
ytest=to_categorical(ytest)

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Initialize a sequential model
# - Define a sequential model

# %%
Model_Seq=tf.keras.Sequential()

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Add a layer
# - Use Dense Layer  with input shape of 4 (according to the feature set) and number of outputs set to 3
# - Apply Softmax on Dense Layer outputs

# %%
from tensorflow.keras.layers import Dense

# %%
Model_Seq.add(Dense(4, activation='relu', input_shape=(4,)))
Model_Seq.add(Dense(4, activation='relu'))
Model_Seq.add(Dense(3, activation='softmax'))

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Compile the model
# - Use SGD as Optimizer
# - Use categorical_crossentropy as loss function
# - Use accuracy as metrics

# %%
Model_Seq.compile(loss='categorical_crossentropy',
              optimizer='SGD',
              metrics=['accuracy'])

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Summarize the model
# - Check model layers
# - Understand number of trainable parameters

# %%
Model_Seq.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 4)                 20
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 15
# =================================================================
# Total params: 55
# Trainable params: 55
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Fit the model
# - Give train data as training features and labels
# - Epochs: 100
# - Give validation data as testing features and labels

# %%
Model_Seq.fit(xtrain,ytrain,validation_data=(xtest,ytest),epochs=100)
# Out:
# Train on 112 samples, validate on 38 samples
# Epoch 1/100
# 112/112 [==============================] - 1s 5ms/sample - loss: 1.5419 - accuracy: 0.3125 - val_loss: 1.3376 - val_accuracy: 0.3947
# Epoch 2/100
# 112/112 [==============================] - 0s 183us/sample - loss: 1.3539 - accuracy: 0.3125 - val_loss: 1.2306 - val_accuracy: 0.3947
# Epoch 3/100
# 112/112 [==============================] - 0s 163us/sample - loss: 1.2527 - accuracy: 0.3125 - val_loss: 1.1735 - val_accuracy: 0.3947
# Epoch 4/100
# 112/112 [==============================] - 0s 179us/sample - loss: 1.1948 - accuracy: 0.3125 - val_loss: 1.1376 - val_accuracy: 0.3947
# Epoch 5/100
# 112/112 [==============================] - 0s 170us/sample - loss: 1.1572 - accuracy: 0.3125 - val_loss: 1.1184 - val_accuracy: 0.3947
# Epoch 6/100
# 112/112 [==============================] - 0s 177us/sample - loss: 1.1352 - accuracy: 0.3125 - val_loss: 1.1046 - val_accuracy: 0.3947
# Epoch 7/100
# 112/112 [==============================] - 0s 155us/sample - loss: 1.1182 - accuracy: 0.3125 - val_loss: 1.0960 - val_accuracy: 0.3947
# Epoch 8/100
# 112/112 [==============================] - 0s 173us/sample - loss: 1.1078 - accuracy: 0.3125 - val_loss: 1.0889 - val_accuracy: 0.3947
# Epoch 9/100
# 112/112 [==============================] - 0s 163us/sample - loss: 1.0981 - accuracy: 0.3125 - val_loss: 1.0841 - val_accuracy: 0.3421
# Epoch 10/100
# 112/112 [==============================] - 0s 157us/sample - loss: 1.0913 - accuracy: 0.2411 - val_loss: 1.0807 - val_accuracy: 0.1579
# Epoch 11/100
# 112/112 [==============================] - 0s 156us/sample - loss: 1.0867 - accuracy: 0.3125 - val_loss: 1.0786 - val_accuracy: 0.3158
# Epoch 12/100
# 112/112 [==============================] - 0s 179us/sample - loss: 1.0844 - accuracy: 0.3393 - val_loss: 1.0768 - val_accuracy: 0.3158
# Epoch 13/100
# 112/112 [==============================] - 0s 195us/sample - loss: 1.0811 - accuracy: 0.3393 - val_loss: 1.0751 - val_accuracy: 0.3158
# Epoch 14/100
# 112/112 [==============================] - 0s 171us/sample - loss: 1.0783 - accuracy: 0.3393 - val_loss: 1.0736 - val_accuracy: 0.3158
# Epoch 15/100
# 112/112 [==============================] - 0s 164us/sample - loss: 1.0761 - accuracy: 0.3393 - val_loss: 1.0722 - val_accuracy: 0.3158
# Epoch 16/100
# 112/112 [==============================] - 0s 167us/sample - loss: 1.0730 - accuracy: 0.3393 - val_loss: 1.0707 - val_accuracy: 0.3158
# Epoch 17/100
# 112/112 [==============================] - 0s 186us/sample - loss: 1.0718 - accuracy: 0.3393 - val_loss: 1.0704 - val_accuracy: 0.3158
# Epoch 18/100
# 112/112 [==============================] - 0s 179us/sample - loss: 1.0691 - accuracy: 0.3393 - val_loss: 1.0685 - val_accuracy: 0.3158
# Epoch 19/100
# 112/112 [==============================] - 0s 148us/sample - loss: 1.0676 - accuracy: 0.3393 - val_loss: 1.0663 - val_accuracy: 0.3158
# Epoch 20/100
# 112/112 [==============================] - 0s 160us/sample - loss: 1.0663 - accuracy: 0.3393 - val_loss: 1.0647 - val_accuracy: 0.3158
# Epoch 21/100
# 112/112 [==============================] - 0s 162us/sample - loss: 1.0655 - accuracy: 0.3393 - val_loss: 1.0631 - val_accuracy: 0.3158
# Epoch 22/100
# 112/112 [==============================] - 0s 152us/sample - loss: 1.0630 - accuracy: 0.3393 - val_loss: 1.0618 - val_accuracy: 0.3158
# Epoch 23/100
# 112/112 [==============================] - 0s 173us/sample - loss: 1.0624 - accuracy: 0.3393 - val_loss: 1.0606 - val_accuracy: 0.3158
# Epoch 24/100
# 112/112 [==============================] - 0s 184us/sample - loss: 1.0600 - accuracy: 0.3393 - val_loss: 1.0592 - val_accuracy: 0.3158
# Epoch 25/100
# 112/112 [==============================] - 0s 185us/sample - loss: 1.0582 - accuracy: 0.3393 - val_loss: 1.0579 - val_accuracy: 0.3158
# Epoch 26/100
# 112/112 [==============================] - 0s 171us/sample - loss: 1.0563 - accuracy: 0.3393 - val_loss: 1.0561 - val_accuracy: 0.3158
# Epoch 27/100
# 112/112 [==============================] - 0s 183us/sample - loss: 1.0545 - accuracy: 0.3393 - val_loss: 1.0541 - val_accuracy: 0.3158
# Epoch 28/100
# 112/112 [==============================] - 0s 222us/sample - loss: 1.0526 - accuracy: 0.3393 - val_loss: 1.0527 - val_accuracy: 0.3158
# Epoch 29/100
# 112/112 [==============================] - 0s 188us/sample - loss: 1.0515 - accuracy: 0.3393 - val_loss: 1.0504 - val_accuracy: 0.3158
# Epoch 30/100
# 112/112 [==============================] - 0s 200us/sample - loss: 1.0494 - accuracy: 0.3393 - val_loss: 1.0490 - val_accuracy: 0.3158
# Epoch 31/100
# 112/112 [==============================] - 0s 199us/sample - loss: 1.0491 - accuracy: 0.3393 - val_loss: 1.0477 - val_accuracy: 0.3158
# Epoch 32/100
# 112/112 [==============================] - 0s 179us/sample - loss: 1.0460 - accuracy: 0.3393 - val_loss: 1.0458 - val_accuracy: 0.3158
# Epoch 33/100
# 112/112 [==============================] - 0s 190us/sample - loss: 1.0438 - accuracy: 0.3393 - val_loss: 1.0443 - val_accuracy: 0.3158
# Epoch 34/100
# 112/112 [==============================] - 0s 147us/sample - loss: 1.0417 - accuracy: 0.3393 - val_loss: 1.0423 - val_accuracy: 0.3158
# Epoch 35/100
# 112/112 [==============================] - 0s 188us/sample - loss: 1.0401 - accuracy: 0.3393 - val_loss: 1.0410 - val_accuracy: 0.3158
# Epoch 36/100
# 112/112 [==============================] - 0s 176us/sample - loss: 1.0375 - accuracy: 0.3393 - val_loss: 1.0394 - val_accuracy: 0.3158
# Epoch 37/100
# 112/112 [==============================] - 0s 177us/sample - loss: 1.0358 - accuracy: 0.3393 - val_loss: 1.0375 - val_accuracy: 0.3158
# Epoch 38/100
# 112/112 [==============================] - 0s 209us/sample - loss: 1.0337 - accuracy: 0.3393 - val_loss: 1.0347 - val_accuracy: 0.3158
# Epoch 39/100
# 112/112 [==============================] - 0s 205us/sample - loss: 1.0307 - accuracy: 0.3393 - val_loss: 1.0320 - val_accuracy: 0.3158
# Epoch 40/100
# 112/112 [==============================] - 0s 238us/sample - loss: 1.0288 - accuracy: 0.3393 - val_loss: 1.0296 - val_accuracy: 0.3158
# Epoch 41/100
# 112/112 [==============================] - 0s 167us/sample - loss: 1.0259 - accuracy: 0.3393 - val_loss: 1.0274 - val_accuracy: 0.3158
# Epoch 42/100
# 112/112 [==============================] - 0s 220us/sample - loss: 1.0233 - accuracy: 0.3393 - val_loss: 1.0255 - val_accuracy: 0.3158
# Epoch 43/100
# 112/112 [==============================] - 0s 174us/sample - loss: 1.0206 - accuracy: 0.3393 - val_loss: 1.0237 - val_accuracy: 0.3158
# Epoch 44/100
# 112/112 [==============================] - 0s 167us/sample - loss: 1.0180 - accuracy: 0.3393 - val_loss: 1.0211 - val_accuracy: 0.3158
# Epoch 45/100
# 112/112 [==============================] - 0s 214us/sample - loss: 1.0156 - accuracy: 0.3393 - val_loss: 1.0177 - val_accuracy: 0.3158
# Epoch 46/100
# 112/112 [==============================] - 0s 152us/sample - loss: 1.0127 - accuracy: 0.3393 - val_loss: 1.0151 - val_accuracy: 0.3158
# Epoch 47/100
# 112/112 [==============================] - 0s 180us/sample - loss: 1.0091 - accuracy: 0.3393 - val_loss: 1.0115 - val_accuracy: 0.3158
# Epoch 48/100
# 112/112 [==============================] - 0s 146us/sample - loss: 1.0065 - accuracy: 0.3393 - val_loss: 1.0079 - val_accuracy: 0.3158
# Epoch 49/100
# 112/112 [==============================] - 0s 156us/sample - loss: 1.0035 - accuracy: 0.3482 - val_loss: 1.0045 - val_accuracy: 0.3158
# Epoch 50/100
# 112/112 [==============================] - 0s 179us/sample - loss: 1.0000 - accuracy: 0.3571 - val_loss: 1.0025 - val_accuracy: 0.3158
# Epoch 51/100
# 112/112 [==============================] - 0s 220us/sample - loss: 0.9965 - accuracy: 0.3482 - val_loss: 0.9989 - val_accuracy: 0.3421
# Epoch 52/100
# 112/112 [==============================] - 0s 143us/sample - loss: 0.9929 - accuracy: 0.3571 - val_loss: 0.9947 - val_accuracy: 0.3421
# Epoch 53/100
# 112/112 [==============================] - 0s 162us/sample - loss: 0.9900 - accuracy: 0.3839 - val_loss: 0.9907 - val_accuracy: 0.3421
# Epoch 54/100
# 112/112 [==============================] - 0s 216us/sample - loss: 0.9858 - accuracy: 0.3929 - val_loss: 0.9872 - val_accuracy: 0.3684
# Epoch 55/100
# 112/112 [==============================] - 0s 218us/sample - loss: 0.9814 - accuracy: 0.4286 - val_loss: 0.9831 - val_accuracy: 0.3947
# Epoch 56/100
# 112/112 [==============================] - 0s 201us/sample - loss: 0.9785 - accuracy: 0.4464 - val_loss: 0.9798 - val_accuracy: 0.4211
# Epoch 57/100
# 112/112 [==============================] - 0s 159us/sample - loss: 0.9731 - accuracy: 0.4643 - val_loss: 0.9760 - val_accuracy: 0.5000
# Epoch 58/100
# 112/112 [==============================] - 0s 168us/sample - loss: 0.9691 - accuracy: 0.5089 - val_loss: 0.9712 - val_accuracy: 0.5000
# Epoch 59/100
# 112/112 [==============================] - 0s 207us/sample - loss: 0.9650 - accuracy: 0.5357 - val_loss: 0.9671 - val_accuracy: 0.5263
# Epoch 60/100
# 112/112 [==============================] - 0s 164us/sample - loss: 0.9597 - accuracy: 0.5714 - val_loss: 0.9631 - val_accuracy: 0.5263
# Epoch 61/100
# 112/112 [==============================] - 0s 158us/sample - loss: 0.9549 - accuracy: 0.5804 - val_loss: 0.9587 - val_accuracy: 0.5526
# Epoch 62/100
# 112/112 [==============================] - 0s 163us/sample - loss: 0.9497 - accuracy: 0.6250 - val_loss: 0.9540 - val_accuracy: 0.5526
# Epoch 63/100
# 112/112 [==============================] - 0s 229us/sample - loss: 0.9443 - accuracy: 0.6161 - val_loss: 0.9487 - val_accuracy: 0.5526
# Epoch 64/100
# 112/112 [==============================] - 0s 171us/sample - loss: 0.9388 - accuracy: 0.6518 - val_loss: 0.9439 - val_accuracy: 0.6053
# Epoch 65/100
# 112/112 [==============================] - 0s 180us/sample - loss: 0.9335 - accuracy: 0.6518 - val_loss: 0.9387 - val_accuracy: 0.6053
# Epoch 66/100
# 112/112 [==============================] - 0s 170us/sample - loss: 0.9273 - accuracy: 0.6696 - val_loss: 0.9337 - val_accuracy: 0.6053
# Epoch 67/100
# 112/112 [==============================] - 0s 161us/sample - loss: 0.9207 - accuracy: 0.6696 - val_loss: 0.9275 - val_accuracy: 0.6053
# Epoch 68/100
# 112/112 [==============================] - 0s 186us/sample - loss: 0.9143 - accuracy: 0.6786 - val_loss: 0.9210 - val_accuracy: 0.6053
# Epoch 69/100
# 112/112 [==============================] - 0s 187us/sample - loss: 0.9080 - accuracy: 0.6875 - val_loss: 0.9150 - val_accuracy: 0.6053
# Epoch 70/100
# 112/112 [==============================] - 0s 199us/sample - loss: 0.9014 - accuracy: 0.6875 - val_loss: 0.9095 - val_accuracy: 0.6053
# Epoch 71/100
# 112/112 [==============================] - 0s 200us/sample - loss: 0.8947 - accuracy: 0.6875 - val_loss: 0.9035 - val_accuracy: 0.6053
# Epoch 72/100
# 112/112 [==============================] - 0s 246us/sample - loss: 0.8878 - accuracy: 0.6875 - val_loss: 0.8972 - val_accuracy: 0.6053
# Epoch 73/100
# 112/112 [==============================] - 0s 180us/sample - loss: 0.8816 - accuracy: 0.6875 - val_loss: 0.8919 - val_accuracy: 0.6053
# Epoch 74/100
# 112/112 [==============================] - 0s 218us/sample - loss: 0.8752 - accuracy: 0.6875 - val_loss: 0.8861 - val_accuracy: 0.6053
# Epoch 75/100
# 112/112 [==============================] - 0s 161us/sample - loss: 0.8699 - accuracy: 0.6875 - val_loss: 0.8805 - val_accuracy: 0.6053
# Epoch 76/100
# 112/112 [==============================] - 0s 156us/sample - loss: 0.8629 - accuracy: 0.6875 - val_loss: 0.8755 - val_accuracy: 0.6053
# Epoch 77/100
# 112/112 [==============================] - 0s 173us/sample - loss: 0.8580 - accuracy: 0.6875 - val_loss: 0.8701 - val_accuracy: 0.6053
# Epoch 78/100
# 112/112 [==============================] - 0s 192us/sample - loss: 0.8517 - accuracy: 0.6875 - val_loss: 0.8653 - val_accuracy: 0.6053
# Epoch 79/100
# 112/112 [==============================] - 0s 182us/sample - loss: 0.8482 - accuracy: 0.6875 - val_loss: 0.8613 - val_accuracy: 0.6053
# Epoch 80/100
# 112/112 [==============================] - 0s 213us/sample - loss: 0.8413 - accuracy: 0.6875 - val_loss: 0.8563 - val_accuracy: 0.6053
# Epoch 81/100
# 112/112 [==============================] - 0s 159us/sample - loss: 0.8362 - accuracy: 0.6875 - val_loss: 0.8508 - val_accuracy: 0.6053
# Epoch 82/100
# 112/112 [==============================] - 0s 151us/sample - loss: 0.8317 - accuracy: 0.6875 - val_loss: 0.8460 - val_accuracy: 0.6053
# Epoch 83/100
# 112/112 [==============================] - 0s 178us/sample - loss: 0.8266 - accuracy: 0.6875 - val_loss: 0.8409 - val_accuracy: 0.6053
# Epoch 84/100
# 112/112 [==============================] - 0s 212us/sample - loss: 0.8222 - accuracy: 0.6875 - val_loss: 0.8363 - val_accuracy: 0.6053
# Epoch 85/100
# 112/112 [==============================] - 0s 159us/sample - loss: 0.8177 - accuracy: 0.6875 - val_loss: 0.8326 - val_accuracy: 0.6053
# Epoch 86/100
# 112/112 [==============================] - 0s 208us/sample - loss: 0.8129 - accuracy: 0.6875 - val_loss: 0.8276 - val_accuracy: 0.6053
# Epoch 87/100
# 112/112 [==============================] - 0s 167us/sample - loss: 0.8086 - accuracy: 0.6875 - val_loss: 0.8224 - val_accuracy: 0.6053
# Epoch 88/100
# 112/112 [==============================] - 0s 167us/sample - loss: 0.8041 - accuracy: 0.6875 - val_loss: 0.8191 - val_accuracy: 0.6053
# Epoch 89/100
# 112/112 [==============================] - 0s 177us/sample - loss: 0.7999 - accuracy: 0.6875 - val_loss: 0.8145 - val_accuracy: 0.6053
# Epoch 90/100
# 112/112 [==============================] - 0s 160us/sample - loss: 0.7954 - accuracy: 0.6875 - val_loss: 0.8104 - val_accuracy: 0.6053
# Epoch 91/100
# 112/112 [==============================] - 0s 164us/sample - loss: 0.7916 - accuracy: 0.6875 - val_loss: 0.8070 - val_accuracy: 0.6053
# Epoch 92/100
# 112/112 [==============================] - 0s 166us/sample - loss: 0.7870 - accuracy: 0.6875 - val_loss: 0.8031 - val_accuracy: 0.6053
# Epoch 93/100
# 112/112 [==============================] - 0s 164us/sample - loss: 0.7830 - accuracy: 0.6875 - val_loss: 0.7991 - val_accuracy: 0.6053
# Epoch 94/100
# 112/112 [==============================] - 0s 160us/sample - loss: 0.7798 - accuracy: 0.6875 - val_loss: 0.7949 - val_accuracy: 0.6053
# Epoch 95/100
# 112/112 [==============================] - 0s 166us/sample - loss: 0.7751 - accuracy: 0.6875 - val_loss: 0.7911 - val_accuracy: 0.6053
# Epoch 96/100
# 112/112 [==============================] - 0s 161us/sample - loss: 0.7711 - accuracy: 0.6875 - val_loss: 0.7875 - val_accuracy: 0.6053
# Epoch 97/100
# 112/112 [==============================] - 0s 240us/sample - loss: 0.7675 - accuracy: 0.6875 - val_loss: 0.7835 - val_accuracy: 0.6053
# Epoch 98/100
# 112/112 [==============================] - 0s 153us/sample - loss: 0.7639 - accuracy: 0.6875 - val_loss: 0.7790 - val_accuracy: 0.6053
# Epoch 99/100
# 112/112 [==============================] - 0s 153us/sample - loss: 0.7607 - accuracy: 0.6875 - val_loss: 0.7761 - val_accuracy: 0.6053
# Epoch 100/100
# 112/112 [==============================] - 0s 170us/sample - loss: 0.7566 - accuracy: 0.6875 - val_loss: 0.7717 - val_accuracy: 0.6053

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Make predictions
# - Predict labels on one row

# %%
Model_Seq.predict(xtest[0:1])
# Out:
# array([[0.12528256, 0.3591153 , 0.5156021 ]], dtype=float32)

# %% [markdown]
# ### Compare the prediction with actual label
# - Print the same row as done in the previous step but of actual labels

# %%
ytest[0:1]
# Out:
# array([[0., 1., 0.]], dtype=float32)

# %% [markdown]
# ---

# %% [markdown]
# # Stock prices dataset
# The data is of tock exchange's stock listings for each trading day of 2010 to 2016.
#
# ## Description
# A brief description of columns.
# - open: The opening market price of the equity symbol on the date
# - high: The highest market price of the equity symbol on the date
# - low: The lowest recorded market price of the equity symbol on the date
# - close: The closing recorded price of the equity symbol on the date
# - symbol: Symbol of the listed company
# - volume: Total traded volume of the equity symbol on the date
# - date: Date of record

# %% [markdown]
# ### Specifying the TensorFlow version
# Running `import tensorflow` will import the default version (currently 1.x). You can use 2.x by running a cell with the `tensorflow_version` magic **before** you run `import tensorflow`.

# %%
# %tensorflow_version 2.x

# %% [markdown]
# ### Import TensorFlow
# Once you have specified a version via this magic, you can run `import tensorflow` as normal and verify which version was imported as follows:

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0

# %% [markdown]
# ### Set random seed

# %%
tf.random.set_seed(42)

# %% [markdown]
# ## Question 1

# %% [markdown]
# ### Load the data
# - load the csv file and read it using pandas
# - file name is prices.csv

# %%
# run this cell to upload file if you are using google colab
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-2b47b44e-1f8a-4e89-a86f-b20d2b3b913e" name="files[]" multiple disabled />
#      <output id="result-2b47b44e-1f8a-4e89-a86f-b20d2b3b913e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving prices.csv to prices.csv

# %%
price_df=pd.read_csv("prices.csv")

# %% [markdown]
# ## Question 2

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Drop columnns
# - drop "date" and "symbol" column from the data

# %%
price_df1=price_df.drop(["date","symbol"],axis=1)

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### Take initial rows
# - Take first 1000 rows from the data
# - This step is done to make the execution faster

# %%
price_df2=price_df1.iloc[0:1000,:]

# %%
price_df2.shape
# Out:
# (1000, 5)

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### Get features and label from the dataset in separate variable
# - Take "open", "close", "low", "high" columns as features
# - Take "volume" column as label
# - Normalize label column by dividing it with 1000000

# %%
X=price_df2.drop(["volume"],axis=1)
Y=price_df2["volume"]

# %%
Y=Y/1000000

# %%
Y.head()
# Out:
# 0    2.1636
# 1    2.3864
# 2    2.4895
# 3    2.0063
# 4    1.4086
# Name: volume, dtype: float64

# %%
X.dtypes
# Out:
# open     float64
# close    float64
# low      float64
# high     float64
# dtype: object

# %%
Y.dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ## Question 5

# %% [markdown]
# ### Convert data
# - Convert features and labels to numpy array
# - Convert their data type to "float32"

# %%
X=np.array(X)
Y=np.array(Y)
X=X.astype("float32")
Y=Y.astype("float32")

# %% [markdown]
# ## Question 6

# %% [markdown]
# ### Normalize data
# - Normalize features
# - Use tf.math.l2_normalize to normalize features
# - You can read more about it here https://www.tensorflow.org/api_docs/python/tf/math/l2_normalize

# %%
X=tf.math.l2_normalize(
    X,
    axis=None,
    epsilon=1e-12,
    name=None
)

# %% [markdown]
# ## Question 7

# %% [markdown]
# ### Define weight and bias
# - Initialize weight and bias with tf.zeros
# - tf.zeros is an initializer that generates tensors initialized to 0
# - Specify the value for shape

# %%
R=tf.zeros(shape=(4,1))
S=tf.zeros(shape=(1))

# %% [markdown]
# ## Question 8

# %% [markdown]
# ### Get prediction
# - Define a function to get prediction
# - Approach: prediction = (X * W) + b; here is X is features

# %%
@tf.function 
def prediction(features,R,S):
  Y_pred=tf.add(tf.matmul(features,R),S)
  return Y_pred

# %% [markdown]
# ### Calculate loss
# - Calculate loss using predictions
# - Define a function to calculate loss
# - We are calculating mean squared error

# %%
@tf.function
def loss(Y_actual,Y_predicted):
  diff=Y_actual-Y_predicted
  Sq=tf.square(diff)
  Avg=tf.reduce_mean(Sq)
  return Avg

# %% [markdown]
# ## Question 9

# %% [markdown]
# ### Define a function to train the model
# 1.   Record all the mathematical steps to calculate Loss
# 2.   Calculate Gradients of Loss w.r.t weights and bias
# 3.   Update Weights and Bias based on gradients and learning rate to minimize loss

# %%
def train(X,Y_actual,R,S,learning_rate=0.01):
  with tf.GradientTape() as t:
    t.watch([R,S])
    CP=prediction(X,R,S)
    CL=loss(Y_actual,CP)

  DW,DB=t.gradient(CL,[R,S])  

  R=R-learning_rate *DW
  S=S-learning_rate *DB

  return R,S

# %% [markdown]
# ## Question 10

# %% [markdown]
# ### Train the model for 100 epochs
# - Observe the training loss at every iteration

# %%
for j in range(100):
  R,S=train(X,Y,R,S)
  print('Current Training loss on iteration',j,loss(Y,prediction(X,R,S)).numpy())
# Out:
# Current Training loss on iteration 0 236.16759
# Current Training loss on iteration 1 235.09299
# Current Training loss on iteration 2 234.06102
# Current Training loss on iteration 3 233.06998
# Current Training loss on iteration 4 232.11781
# Current Training loss on iteration 5 231.20381
# Current Training loss on iteration 6 230.32585
# Current Training loss on iteration 7 229.48265
# Current Training loss on iteration 8 228.67297
# Current Training loss on iteration 9 227.89539
# Current Training loss on iteration 10 227.14832
# Current Training loss on iteration 11 226.43114
# Current Training loss on iteration 12 225.74234
# Current Training loss on iteration 13 225.0808
# Current Training loss on iteration 14 224.44553
# Current Training loss on iteration 15 223.835
# Current Training loss on iteration 16 223.24931
# Current Training loss on iteration 17 222.68655
# Current Training loss on iteration 18 222.14595
# Current Training loss on iteration 19 221.62688
# Current Training loss on iteration 20 221.12842
# Current Training loss on iteration 21 220.6498
# Current Training loss on iteration 22 220.18993
# Current Training loss on iteration 23 219.74841
# Current Training loss on iteration 24 219.32425
# Current Training loss on iteration 25 218.91705
# Current Training loss on iteration 26 218.52579
# Current Training loss on iteration 27 218.15027
# Current Training loss on iteration 28 217.78957
# Current Training loss on iteration 29 217.44315
# Current Training loss on iteration 30 217.11034
# Current Training loss on iteration 31 216.79077
# Current Training loss on iteration 32 216.48412
# Current Training loss on iteration 33 216.18932
# Current Training loss on iteration 34 215.90611
# Current Training loss on iteration 35 215.63437
# Current Training loss on iteration 36 215.37334
# Current Training loss on iteration 37 215.12263
# Current Training loss on iteration 38 214.88185
# Current Training loss on iteration 39 214.65053
# Current Training loss on iteration 40 214.42859
# Current Training loss on iteration 41 214.21527
# Current Training loss on iteration 42 214.01044
# Current Training loss on iteration 43 213.81369
# Current Training loss on iteration 44 213.62482
# Current Training loss on iteration 45 213.44333
# Current Training loss on iteration 46 213.2691
# Current Training loss on iteration 47 213.10179
# Current Training loss on iteration 48 212.94106
# Current Training loss on iteration 49 212.78687
# Current Training loss on iteration 50 212.63857
# Current Training loss on iteration 51 212.4961
# Current Training loss on iteration 52 212.35948
# Current Training loss on iteration 53 212.22816
# Current Training loss on iteration 54 212.10205
# Current Training loss on iteration 55 211.98093
# Current Training loss on iteration 56 211.86461
# Current Training loss on iteration 57 211.75293
# Current Training loss on iteration 58 211.64558
# Current Training loss on iteration 59 211.54266
# Current Training loss on iteration 60 211.44374
# Current Training loss on iteration 61 211.34874
# Current Training loss on iteration 62 211.2575
# Current Training loss on iteration 63 211.16982
# Current Training loss on iteration 64 211.08572
# Current Training loss on iteration 65 211.00484
# Current Training loss on iteration 66 210.92729
# Current Training loss on iteration 67 210.85278
# Current Training loss on iteration 68 210.78104
# Current Training loss on iteration 69 210.71225
# Current Training loss on iteration 70 210.64633
# Current Training loss on iteration 71 210.58289
# Current Training loss on iteration 72 210.52199
# Current Training loss on iteration 73 210.46347
# Current Training loss on iteration 74 210.4073
# Current Training loss on iteration 75 210.3533
# Current Training loss on iteration 76 210.30153
# Current Training loss on iteration 77 210.2518
# Current Training loss on iteration 78 210.204
# Current Training loss on iteration 79 210.15811
# Current Training loss on iteration 80 210.1141
# Current Training loss on iteration 81 210.0717
# Current Training loss on iteration 82 210.03108
# Current Training loss on iteration 83 209.99205
# Current Training loss on iteration 84 209.95453
# Current Training loss on iteration 85 209.91852
# Current Training loss on iteration 86 209.88396
# Current Training loss on iteration 87 209.85075
# Current Training loss on iteration 88 209.81891
# Current Training loss on iteration 89 209.78818
# Current Training loss on iteration 90 209.75874
# Current Training loss on iteration 91 209.73053
# Current Training loss on iteration 92 209.70349
# Current Training loss on iteration 93 209.67744
# Current Training loss on iteration 94 209.65225
# Current Training loss on iteration 95 209.62833
# Current Training loss on iteration 96 209.6052
# Current Training loss on iteration 97 209.58302
# Current Training loss on iteration 98 209.56174
# Current Training loss on iteration 99 209.5413

# %% [markdown]
# ### Observe values of Weight
# - Print the updated values

# %%
print(R)
# Out:
# tf.Tensor(
# [[0.05478281]
#  [0.05488192]
#  [0.05422736]
#  [0.05533117]], shape=(4, 1), dtype=float32)

# %% [markdown]
# ### Observe values of Bias
# - Print the updated values

# %%
print(S)
# Out:
# tf.Tensor([4.607657], shape=(1,), dtype=float32)
